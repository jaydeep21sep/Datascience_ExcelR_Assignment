# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/Rishi/Downloads/delivery_time.csv")

# %%
data
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Delivery Time, Sorting Time]
# Index: []

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x130725033d0>,
#   <matplotlib.lines.Line2D at 0x130725036a0>,
#   <matplotlib.lines.Line2D at 0x130725147f0>,
#   <matplotlib.lines.Line2D at 0x13072514ac0>],
#  'caps': [<matplotlib.lines.Line2D at 0x13072503970>,
#   <matplotlib.lines.Line2D at 0x13072503c40>,
#   <matplotlib.lines.Line2D at 0x13072514d90>,
#   <matplotlib.lines.Line2D at 0x130725210a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x13072503100>,
#   <matplotlib.lines.Line2D at 0x13072514520>],
#  'medians': [<matplotlib.lines.Line2D at 0x13072503f10>,
#   <matplotlib.lines.Line2D at 0x13072521370>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13072514220>,
#   <matplotlib.lines.Line2D at 0x13072521640>],
#  'means': []}

# %%
data.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df1=scaler.fit_transform(data)
scaled_df=pd.DataFrame(df1,columns=data.columns)
scaled_df.head()
# Out:
#    Delivery Time  Sorting Time
# 0       0.619048         1.000
# 1       0.261905         0.250
# 2       0.559524         0.500
# 3       0.761905         0.875
# 4       1.000000         1.000

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
df2 = scaler.fit_transform(data)
scaled_df = pd.DataFrame(df2, columns = data.columns)
scaled_df.head()
# Out:
#    Delivery Time  Sorting Time
# 0       0.849867      1.535625
# 1      -0.664490     -0.882984
# 2       0.597474     -0.076781
# 3       1.455610      1.132523
# 4       2.465181      1.535625

# %%
data=data.rename({'Delivery Time':'delivery_time', 'Sorting Time':'sorting_time'},axis=1)
data
# Out:
#     delivery_time  sorting_time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
import statsmodels.formula.api as smf
model = smf.ols(formula ='delivery_time~sorting_time', data = data).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          delivery_time   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     40.80
# Date:                Sun, 28 May 2023   Prob (F-statistic):           3.98e-06
# Time:                        12:28:47   Log-Likelihood:                -51.357
# No. Observations:                  21   AIC:                             106.7
# Df Residuals:                      19   BIC:                             108.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        6.5827      1.722      3.823      0.001       2.979      10.186
# sorting_time     1.6490      0.258      6.387      0.000       1.109       2.189
# ==============================================================================
# Omnibus:                        3.649   Durbin-Watson:                   1.248
# Prob(Omnibus):                  0.161   Jarque-Bera (JB):                2.086
# Skew:                           0.750   Prob(JB):                        0.352
# Kurtosis:                       3.367   Cond. No.                         18.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q')
plt.title("Nomral Q-Q plot of residuals")
plt.show()

# %%
np.where(model.resid>10)
# Out:
# (array([], dtype=int64),)

# %%
def get_standardize_values( vals): 
  return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardize_values(model.fittedvalues), get_standardize_values(model.resid))
plt.ylabel('Standardize Residual values')
plt.xlabel('Standardize Fitted values')
plt.title('Residual Plot')
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "sorting_time", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
fig = plt.subplots(figsize=(20,8))
plt.stem(np.arange(len(data)), np.round(c,3))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c), np.max(c))
# Out:
# (4, 0.4620530412650316)

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
k = data.shape[1]
n = data.shape[0]
leverage_cutoff = 3*(k+1)/n
leverage_cutoff
# Out:
# 0.42857142857142855

# %%
final_ml_v=smf.ols(formula ='delivery_time~sorting_time', data = data).fit()

# %%
(final_ml_v.rsquared,final_ml_v.aic)
# Out:
# (0.6822714748417231, 106.71400170798609)

# %%
newdata = pd.Series([5,10])

# %%
data_pred = pd.DataFrame(newdata, columns = ['sorting_time'])

# %%
data_pred
# Out:
#    sorting_time
# 0             5
# 1            10

# %%
model.predict(data_pred)
# Out:
# 0    14.827833
# 1    23.072933
# dtype: float64
